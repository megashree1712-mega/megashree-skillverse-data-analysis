# %% [markdown]
# Day 1

# %%
#Import required libraries
import numpy as np
import pandas as pd

print("Numpy imported successfully")
print("Pandas imported successfully")
# Out:
# Numpy imported successfully
# Pandas imported successfully

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# Load dataset
df_airline = pd.read_csv("/content/airlines_flights_data.csv")

print("Dataset loaded successfully")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4843/2252582940.py in <cell line: 0>()
#       1 # Load dataset
# ----> 2 df_airline = pd.read_csv("/content/airlines_flights_data.csv")
#       3
#       4 print("Dataset loaded successfully")
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/airlines_flights_data.csv'

# %%
#display first  5 rows
df_airline.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/1025095741.py in <cell line: 0>()
#       1 #display first  5 rows
# ----> 2 df_airline.head()
#
# NameError: name 'df_airline' is not defined

# %%
# Diplay last  5  rows
df_airline.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/642480701.py in <cell line: 0>()
#       1 # Diplay last  5  rows
# ----> 2 df_airline.tail()
#
# NameError: name 'df_airline' is not defined

# %% [markdown]
# Day 2
#
# task :Load Dataset Airline and apply all thee pandas operations

# %%
# Load dataset
df_airline = pd.read_csv("/content/airlines_flights_data.csv")

print("Dataset loaded successfully")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4843/2252582940.py in <cell line: 0>()
#       1 # Load dataset
# ----> 2 df_airline = pd.read_csv("/content/airlines_flights_data.csv")
#       3
#       4 print("Dataset loaded successfully")
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/airlines_flights_data.csv'

# %%
#code1
df_airline.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/3439059782.py in <cell line: 0>()
#       1 #code1
# ----> 2 df_airline.head()
#
# NameError: name 'df_airline' is not defined

# %%
#code2
df_airline.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/3930115747.py in <cell line: 0>()
#       1 #code2
# ----> 2 df_airline.tail()
#
# NameError: name 'df_airline' is not defined

# %%
#code3
df_airline.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/3347594410.py in <cell line: 0>()
#       1 #code3
# ----> 2 df_airline.shape
#
# NameError: name 'df_airline' is not defined

# %%
#code4
df_airline.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/1728661602.py in <cell line: 0>()
#       1 #code4
# ----> 2 df_airline.columns
#
# NameError: name 'df_airline' is not defined

# %%
#code 5
df_airline.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/1130355196.py in <cell line: 0>()
#       1 #code 5
# ----> 2 df_airline.dtypes
#
# NameError: name 'df_airline' is not defined

# %%
#code6
df_airline.info()

# %%
#code 7
df_airline.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/512764191.py in <cell line: 0>()
#       1 #code 7
# ----> 2 df_airline.describe()
#
# NameError: name 'df_airline' is not defined

# %%
#code 8
df_airline["airline"]

# %%
#code9
df_airline[["airline","flight"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/97144117.py in <cell line: 0>()
#       1 #code9
# ----> 2 df_airline[["airline","flight"]]
#
# NameError: name 'df_airline' is not defined

# %%
#code10
df_airline.loc[:,:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/1561745947.py in <cell line: 0>()
#       1 #code10
# ----> 2 df_airline.loc[:,:]
#
# NameError: name 'df_airline' is not defined

# %%
#code11
df_airline.iloc[:,:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/815503445.py in <cell line: 0>()
#       1 #code11
# ----> 2 df_airline.iloc[:,:]
#
# NameError: name 'df_airline' is not defined

# %%
#code12

df_airline[df_airline["price"] > 10000]

# %%
#code13
df_airline["airline"].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/2041686705.py in <cell line: 0>()
#       1 #code13
# ----> 2 df_airline["airline"].unique()
#
# NameError: name 'df_airline' is not defined

# %%
#code14
df_airline["airline"].value_counts()

# %%
#code15
df_airline["price"].sum()

# %%
#code 16
df_airline["price"].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/1847143500.py in <cell line: 0>()
#       1 #code 16
# ----> 2 df_airline["price"].mean()
#
# NameError: name 'df_airline' is not defined

# %%
#code 17
df_airline["price"].max()

# %%
#code 18
df_airline["price"].min()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/396534212.py in <cell line: 0>()
#       1 #code 18
# ----> 2 df_airline["price"].min()
#
# NameError: name 'df_airline' is not defined

# %% [markdown]
# Day 3

# %%
# Load dataset
df_airline = pd.read_csv("/content/airlines_flights_data.csv")

print("Dataset loaded successfully")

# %% [markdown]
# Task 1: Inspect the airline dataset and display
# First 10 rows
# Last 10 rows
# Number of rows and columns
# All the column names

# %%
# code

display(df_airline.head(10))

display(df_airline.tail(10))

print("Shape:", df_airline.shape)

print("Columns:")
print(df_airline.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/3401751815.py in <cell line: 0>()
#       1 # code
#       2
# ----> 3 display(df_airline.head(10))
#       4
#       5 display(df_airline.tail(10))
#
# NameError: name 'df_airline' is not defined

# %% [markdown]
# Task 2: Select important flight columns and display first 10 records names of the columns namely
# airline
# source_city
# destination_city
# class
# duration
# price

# %%
# code

df_airline[
    ["airline", "source_city", "destination_city", "class", "duration", "price"]
].head(10)

# %% [markdown]
# Task 3: Find expensive flights, where price is greater than 20000. Display the 10 records.

# %%
# code

expensive_flights = df_airline[df_airline["price"] > 20000]

print("Number of Flights:", len(expensive_flights))

display(expensive_flights.head(10))

# %% [markdown]
# Task 4: Filter by airline. Find flights operated uniquely.

# %%
# code

flights_by_airline = df_airline.groupby('airline')['flight'].unique()

print(flights_by_airline)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/862761508.py in <cell line: 0>()
#       1 # code
#       2
# ----> 3 flights_by_airline = df_airline.groupby('airline')['flight'].unique()
#       4
#       5 print(flights_by_airline)
#
# NameError: name 'df_airline' is not defined

# %% [markdown]
# Task 5: Filter by class. Find flights belonging to the economy class

# %%
# code

economy_flights = df_airline[df_airline['class'] == 'Economy']

print(economy_flights)

# %% [markdown]
# Task 6: Multiple Conditions
# Find flights where price is greater than 50000 and duration is greater than 10 hours.

# %%
# code

result = df_airline[
    (df_airline["price"] > 50000) &
    (df_airline["duration"] > 10)
]

display(result.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/3077405314.py in <cell line: 0>()
#       1 # code
#       2
# ----> 3 result = df_airline[
#       4     (df_airline["price"] > 50000) &
#       5     (df_airline["duration"] > 10)
#
# NameError: name 'df_airline' is not defined

# %% [markdown]
# Task 7: Airline distribution. Find
# Unique airlines
# Number of airlines
# Number of flights for each airline

# %%
# code

print("airline:")
print(df_airline["airline"].unique())

print("\nNumber of airline:")
print(df_airline["airline"].nunique())

print("\nNumber of flights for each airline:")
print(df_airline["airline"].value_counts())

# %% [markdown]
# Task 8: Understand Source_city. Find
# Unique Source_city
# Number of Source_city
# Number of Source_city for each airline

# %%
# code

print("Source_city:")
print(df_airline["source_city"].unique())

print("\nNumber of Source_city:")
print(df_airline["source_city"].nunique())

print("\nNumber of Source_city for each airline:")
print(df_airline["source_city"].value_counts())
# Out:
# Source_city:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/2505334131.py in <cell line: 0>()
#       2
#       3 print("Source_city:")
# ----> 4 print(df_airline["source_city"].unique())
#       5
#       6 print("\nNumber of Source_city:")
#
# NameError: name 'df_airline' is not defined

# %% [markdown]
# Task 9: Price Analysis. Calculate
#
# Total price
#
# Average price
#
# Median price
#
# Maximum price
#
# Minimum price

# %%
# code

print("Total price:", df_airline["price"].sum())
print("Average price:", df_airline["price"].mean())
print("Median price:", df_airline["price"].median())
print("Maximum price:", df_airline["price"].max())
print("Minimum price:", df_airline["price"].min())

# %% [markdown]
# Task 10: Duration Analysis. Calculate
# Total duration
# Average duration
# Median duration
# Maximum duration
# Minimum duration

# %%
# code

print("Total duration:", df_airline["duration"].sum())
print("Average duration:", df_airline["duration"].mean())
print("Median duration:", df_airline["duration"].median())
print("Maximum duration:", df_airline["duration"].max())
print("Minimum duration:", df_airline["duration"].min())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/3304009086.py in <cell line: 0>()
#       1 # code
#       2
# ----> 3 print("Total duration:", df_airline["duration"].sum())
#       4 print("Average duration:", df_airline["duration"].mean())
#       5 print("Median duration:", df_airline["duration"].median())
#
# NameError: name 'df_airline' is not defined

# %% [markdown]
# Day 4 & 5

# %%
# Load dataset
df_airline = pd.read_csv("/content/airlines_flights_data.csv")

print("Dataset loaded successfully")

# %%
airline_col = 'airline'
dep_col = 'departure_time'
origin_col = 'source_city'
dest_col = 'destination_city'

task1_airline = df_airline.groupby(airline_col)[dep_col].count().reset_index(name='Flight_Count')

print(task1_airline.head(5))

# %%
task2_airline = df_airline.groupby([origin_col, dest_col]).agg(
    Flight_Count=(dep_col, 'count')
).reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/3495580373.py in <cell line: 0>()
# ----> 1 task2_airline = df_airline.groupby([origin_col, dest_col]).agg(
#       2     Flight_Count=(dep_col, 'count')
#       3 ).reset_index()
#
# NameError: name 'df_airline' is not defined

# %%
task3_airline = df_airline.groupby(airline_col).agg(
    Total_Flight_Count=(dep_col, 'count'),
).reset_index()
print(task3_airline.head(5))

# %%
task4_airline = (df_airline.groupby(origin_col)
                 .size()
                 .reset_index(name='Total_Flights')
                 .sort_values(by='Total_Flights', ascending=False)
                 .head(5))

print(task4_airline)

# %%
arr_col = 'arrival_time'

task5_airline = df_airline.groupby(airline_col).agg(
    Total_Flights=(dep_col, 'count')
).reset_index()

print(task5_airline.head(5))

# %%
task6_airline = df_airline.groupby(origin_col).filter(lambda x: x[dep_col].count() > 10000)

print("Qualified Origin Airports:", task6_airline[origin_col].unique())
print("Hub Flights Retained:", len(task6_airline))

# %%
task7_airline = df_airline.groupby(airline_col).agg(
    Total_Flights=(dep_col, 'count')
).reset_index()

print(task7_airline.sort_values(by='Total_Flights', ascending=False).head(5))

# %%
task8_airline = df_airline.groupby(airline_col).size().nlargest(5).reset_index(name='Total_Flights')
print("Top 5 airlines by total flights:")
print(task8_airline)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/420551188.py in <cell line: 0>()
# ----> 1 task8_airline = df_airline.groupby(airline_col).size().nlargest(5).reset_index(name='Total_Flights')
#       2 print("Top 5 airlines by total flights:")
#       3 print(task8_airline)
#
# NameError: name 'df_airline' is not defined

# %%
task9_airline = df_airline.groupby(airline_col)[dep_col].value_counts().unstack(fill_value=0)
print("Departure Time Distribution by Airline (Counts):")
print(task9_airline.head(5))

# %%
task10_airline = (df_airline.groupby([origin_col, dest_col])
                  .size()
                  .reset_index(name='Flight_Count')
                  .sort_values(by='Flight_Count', ascending=False)
                  .head(10))

print(task10_airline)

# %% [markdown]
# Day 6&7

# %%
# Load dataset
df_airline = pd.read_csv("/content/airlines_flights_data.csv")

print("Dataset loaded successfully")

# %% [markdown]
# Task 1:Calculate Mean flight price per airline using transform ()

# %%
df_airline['Avg_Airline_Price'] = df_airline.groupby('airline')['price'].transform('mean')
display(df_airline.head())

# %% [markdown]
# Task 2 : Calculate price deviation from Airline average

# %%
df_airline['Price_Difference'] = df_airline['price'] - df_airline['Avg_Airline_Price']
display(df_airline.head())

# %% [markdown]
# Task 3: Create pivot table of average price by source city and class

# %%
pivot_table = pd.pivot_table(df_airline, index='source_city', columns='class', values='price', aggfunc='mean')
display(pivot_table)

# %% [markdown]
# Task 4: Categorize Duration into Flight Distance Categories

# %%
bins = [0, 6, 12, df_airline['duration'].max()]
labels = ['Short Haul', 'Medium Haul', 'Long Haul']
df_airline['Flight_Category'] = pd.cut(df_airline['duration'], bins=bins, labels=labels, right=False)
display(df_airline.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/4175194659.py in <cell line: 0>()
# ----> 1 bins = [0, 6, 12, df_airline['duration'].max()]
#       2 labels = ['Short Haul', 'Medium Haul', 'Long Haul']
#       3 df_airline['Flight_Category'] = pd.cut(df_airline['duration'], bins=bins, labels=labels, right=False)
#       4 display(df_airline.head())
#
# NameError: name 'df_airline' is not defined

# %% [markdown]
# Task 5: Extract Flight Prefix Code using Vectorized String Operations

# %%
df_airline['Flight_Prefix'] = df_airline['flight'].str.split('-').str[0]
display(df_airline.head())

# %% [markdown]
# Task 6: Filter Flights Departing in Early Morning or Morning with Price Above Median

# %%
median_price = df_airline['price'].median()

filtered_flights = df_airline[
    (df_airline['departure_time'].isin(['Early_Morning', 'Morning'])) &
    (df_airline['price'] > median_price)
]

display(filtered_flights.head())

# %% [markdown]
# Task 7 :Create a route column combining source and destination cities

# %%
df_airline['Route'] = df_airline['source_city'] + ' > ' + df_airline['destination_city']
display(df_airline.head())

# %% [markdown]
# Task 8: Calculate Ranking of Flights by Price within Each Airline

# %%
df_airline['Price_Rank_Within_Airline'] = df_airline.groupby('airline')['price'].rank(ascending=False, method='min')
display(df_airline.sort_values(by=['airline', 'Price_Rank_Within_Airline']).head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/988771984.py in <cell line: 0>()
# ----> 1 df_airline['Price_Rank_Within_Airline'] = df_airline.groupby('airline')['price'].rank(ascending=False, method='min')
#       2 display(df_airline.sort_values(by=['airline', 'Price_Rank_Within_Airline']).head())
#
# NameError: name 'df_airline' is not defined

# %% [markdown]
# Task 9: Cross-Tabulate Counts of Flights between Airline and Stops

# %%
cross_tab_flights_stops = pd.crosstab(df_airline['airline'], df_airline['stops'])
display(cross_tab_flights_stops)

# %% [markdown]
# Task 10: Identify Top 3 Longest Duration Flights for Each Airline

# %%
top_longest_flights = df_airline.groupby('airline').apply(lambda x: x.nlargest(3, 'duration')).reset_index(drop=True)
display(top_longest_flights)

# %% [markdown]
# Day 8&9

# %%
# Loading dataset
df_airline = pd.read_csv("/content/airlines_flights_data.csv")

print("Dataset loaded successfully")

# %% [markdown]
# Task 1 :Plot Flight price distribution with KDE

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(df_airline['price'], kde=True)
plt.title('Distribution of Flight Prices with KDE Overlay')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Task 2: Comparative box plot of price across Airlines

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 7))
sns.boxplot(x='airline', y='price', data=df_airline)
plt.title('Price Distribution Across Airlines')
plt.xlabel('Airline')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Task 3: Violin Plot of Price by Ticket Class

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.violinplot(x='class', y='price', data=df_airline)
plt.title('Price Distribution Across Travel Class (Violin Plot)')
plt.xlabel('Travel Class')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# Task 4: Flight Duration vs. Price Scatter Plot split by Class

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 7))
sns.scatterplot(x='duration', y='price', hue='class', alpha=0.6, data=df_airline)
plt.title('Flight Duration vs. Price, by Class')
plt.xlabel('Duration (hours)')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# Task 5: Heatmap Matrix of Mean Prices between Source and Destination

# %%
import seaborn as sns
import matplotlib.pyplot as plt

price_matrix = df_airline.pivot_table(index='source_city', columns='destination_city', values='price', aggfunc='mean')

plt.figure(figsize=(10, 8))
sns.heatmap(price_matrix, annot=True, fmt='.0f', cmap='viridis')
plt.title('Mean Flight Price between Source and Destination Cities')
plt.xlabel('Destination City')
plt.ylabel('Source City')
plt.show()

# %% [markdown]
# Task 6: Average Price by Departure Time Bar Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the average price for each departure time slot
average_price_by_departure = df_airline.groupby('departure_time')['price'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='departure_time', y='price', data=average_price_by_departure, palette='viridis', hue='departure_time', legend=False)
plt.title('Average Flight Price by Departure Time')
plt.xlabel('Departure Time')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Task 7: Correlation Matrix of Numerical Flight Attributes

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a copy to avoid modifying the original DataFrame if 'stops' is needed elsewhere in its original format
df_corr = df_airline.copy()

# Convert 'stops' to a numerical representation
stop_mapping = {'zero': 0, 'one': 1, 'two_or_more': 2}
df_corr['stops_numeric'] = df_corr['stops'].map(stop_mapping)

# Select numerical columns for correlation
correlation_data = df_corr[['duration', 'price', 'stops_numeric']]

# Compute the correlation matrix
correlation_matrix = correlation_data.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix of Numerical Flight Attributes')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4843/1287921924.py in <cell line: 0>()
#       3
#       4 # Create a copy to avoid modifying the original DataFrame if 'stops' is needed elsewhere in its original format
# ----> 5 df_corr = df_airline.copy()
#       6
#       7 # Convert 'stops' to a numerical representation
#
# NameError: name 'df_airline' is not defined

# %% [markdown]
# Task 8: Horizontal Countplot of Flights per Airline

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.countplot(y='airline', data=df_airline, order=df_airline['airline'].value_counts().index, palette='viridis', hue='airline', legend=False)
plt.title('Number of Flights per Airline')
plt.xlabel('Number of Flights')
plt.ylabel('Airline')
plt.show()

# %% [markdown]
# Task 9: FacetGrid / Catplot Comparison across Stops

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the order for the 'stops' column for better visualization
stops_order = ['zero', 'one', 'two_or_more']

# Create a catplot to compare flight prices across stops categorized by travel class
g = sns.catplot(x='stops', y='price', col='class', data=df_airline, kind='box', order=stops_order, height=4, aspect=0.8, palette='viridis', hue='stops', legend=False)

g.set_axis_labels("Number of Stops", "Price")
g.set_titles("{col_name} Class")
plt.suptitle('Flight Price Distribution across Stops by Travel Class', y=1.02) # Adjust suptitle position
plt.show()

# %% [markdown]
# Task 10: 100-Flight Moving Average Price Trend Simulation

# %%
df_airline['Rolling_Mean_Price'] = df_airline['price'].rolling(window=100).mean()
display(df_airline.head())

# %% [markdown]
# Day 10&11

# %%
# AIRLINE DATASET

import kagglehub

# Download latest version
path = kagglehub.dataset_download("rohitgrewal/airlines-flights-data")

print("Path to dataset files:", path)


import os

print(os.listdir(path))


import pandas as pd

df = pd.read_csv(os.path.join(path, "airlines_flights_data.csv"))

print( "Dataset loaded successfully")

# %% [markdown]
# Task 1: Plotly Interactive Flight Price Histogram
#
# AI Prompt for Code Generation: "Create an

# %%
import plotly.express as px

fig = px.histogram(df_airline, x='price', color='class', marginal='box',
                   title='Interactive Flight Price Distribution by Travel Class',
                   labels={'price': 'Flight Price', 'count': 'Number of Flights'})
fig.update_layout(bargap=0.1) # Add some gap between bars for better visibility
fig.show()

# %% [markdown]
# Task 2: Interactive 3D Scatter (Duration vs. Price vs. Days Left)
#
# AI Prompt for Code Generation: "Plot an interactive 3D scatter plot of duration, price, and days_left using http://px.scatter_3d."

# %%
import plotly.express as px

fig = px.scatter_3d(df_airline, x='duration', y='price', z='days_left',
                    color='class', # Color points by travel class
                    symbol='stops', # Use different symbols for number of stops
                    hover_data=['airline', 'source_city', 'destination_city'], # Display additional info on hover
                    title='Interactive 3D Scatter Plot: Duration vs. Price vs. Days Left')
fig.update_layout(scene=dict(
                  xaxis_title='Duration (hours)',
                  yaxis_title='Price',
                  zaxis_title='Days Left Until Departure'))
fig.show()

# %% [markdown]
# Task 3: Interactive Route Matrix Heatmap
#
# AI Prompt for Code Generation: "Create an interactive density heatmap of source_city vs destination_city colored by average price.

# %%
import plotly.express as px

# Create a pivot table for mean price between source and destination cities
mean_price_matrix_plotly = df_airline.pivot_table(index='source_city', columns='destination_city', values='price', aggfunc='mean')

# Reset index to use source_city as a column for px.density_heatmap
mean_price_matrix_plotly = mean_price_matrix_plotly.reset_index()

# Melt the DataFrame to long format for px.density_heatmap
# Note: px.density_heatmap can take wide format directly, but flattening makes x,y,z mapping easier
# For px.density_heatmap, it expects a DataFrame with x, y, and optionally z values if already aggregated.
# If using a pivot table, it's better to use px.imshow for direct matrix visualization or melt for px.density_heatmap

# Re-shaping for px.density_heatmap to properly interpret 'x', 'y', 'z'
df_heatmap = mean_price_matrix_plotly.melt(id_vars='source_city', var_name='destination_city', value_name='average_price')

fig = px.density_heatmap(df_heatmap, x='destination_city', y='source_city', z='average_price',
                         title='Interactive Mean Flight Price Matrix (Source vs. Destination)',
                         labels={'source_city': 'Source City', 'destination_city': 'Destination City', 'average_price': 'Avg Price'},
                         color_continuous_scale=px.colors.sequential.Viridis)

fig.update_layout(xaxis_title='Destination City', yaxis_title='Source City')
fig.show()

# %% [markdown]
# Task 4: Parallel Categories Chart for Flight Attributes
#
# AI Prompt for Code Generation: "Create a parallel categories diagram showing flows across airline -> source_city -> class."

# %% [markdown]
# Task 5: Animated Scatter Plot of Price vs Duration across Departure Times
#
# AI Prompt for Code Generation: "Animate flight duration vs price using departure_time as animation_frame."

# %%
import plotly.express as px

fig = px.scatter(df_airline,
                 x='duration',
                 y='price',
                 animation_frame='departure_time',
                 animation_group='flight', # Group by flight to ensure consistent animation of individual flights
                 color='class', # Color points by travel class
                 symbol='stops', # Use different symbols for number of stops
                 hover_data=['airline', 'source_city', 'destination_city'], # Display additional info on hover
                 title='Animated Scatter Plot: Price vs. Duration Across Departure Times',
                 log_y=True, # Logarithmic scale for price might be useful for better visualization of lower prices
                 size_max=10)

fig.show()

# %% [markdown]
# Task 6: Interactive Violin Plot of Flight Prices across Airlines
#
# AI Prompt for Code Generation: "Create a Plotly violin plot of prices by airline split by class."

# %%
import plotly.express as px

fig = px.violin(df_airline, x='airline', y='price', color='class',
                box=True, # Show box plots inside the violins
                points='outliers', # Display outlier points
                title='Interactive Violin Plot of Flight Prices by Airline and Class',
                labels={'airline': 'Airline', 'price': 'Flight Price', 'class': 'Travel Class'})

fig.update_traces(quartilemethod='exclusive') # A common choice for quartile calculation
fig.show()

# %% [markdown]
# Task 7: Hierarchical Airline Treemap
#
# AI Prompt for Code Generation: "Build a Treemap hierarchy of airline -> source_city -> destination_city scaled by price."

# %%
import plotly.express as px

# Aggregate the data to get the sum of prices for each unique path
df_treemap = df_airline.groupby(['airline', 'source_city', 'destination_city'])['price'].sum().reset_index()

fig = px.treemap(df_treemap,
                 path=['airline', 'source_city', 'destination_city'],
                 values='price',
                 color='price', # Color based on price
                 hover_data=['airline', 'source_city', 'destination_city', 'price'], # Show details on hover
                 title='Hierarchical Treemap: Airline -> Source City -> Destination City (Scaled by Price)',
                 color_continuous_scale='viridis') # Choose a color scale

fig.show()

# %% [markdown]
# Task 8: Interactive Polar / Radar Chart Simulation
#
# AI Prompt for Code Generation: "Create a Polar Radar chart comparing mean price across airlines using Plotly Graph Objects."

# %%
import plotly.graph_objects as go

# Calculate the mean price for each airline
mean_price_by_airline = df_airline.groupby('airline')['price'].mean().reset_index()

# Create a Polar/Radar chart
fig = go.Figure(data=go.Scatterpolar(
    r=mean_price_by_airline['price'],
    theta=mean_price_by_airline['airline'],
    fill='toself',
    name='Mean Price'
))
fig.update_layout(
    polar=dict(
        radialaxis=dict(
            visible=True,
            range=[0, mean_price_by_airline['price'].max() * 1.1] # Set range a bit higher than max price
        )),
    showlegend=False,
    title='Interactive Polar Chart: Mean Price Across Airlines'
)

fig.show()

# %% [markdown]
# Task 9: Custom Hover Template Scatter Plot
#
# AI Prompt for Code Generation: "Create a Plotly scatter plot with custom hover templates displaying formatted flight details."

# %%
import plotly.express as px

fig = px.scatter(df_airline,
                 x='duration',
                 y='price',
                 color='class', # Color by travel class
                 hover_name='flight', # Show flight ID as hover name
                 title='Interactive Scatter Plot with Custom Hover Template',
                 labels={'duration': 'Duration (hours)', 'price': 'Flight Price'})

# Define a custom hover template
fig.update_traces(hovertemplate="""
<b>Flight Details:</b><br><br>
Airline: %{customdata[0]}<br>
Source: %{customdata[1]}<br>
Destination: %{customdata[2]}<br>
Duration: %{x} hrs<br>
Price: $%{y}<br>
<extra></extra>
""")

fig.show()

# %% [markdown]
# Task 10: Multi-Panel Interactive Subplots Container
#
# AI Prompt for Code Generation: "Create a multi-panel subplot layout combining a Bar chart and a Scatter plot using Plotly graph objects."

# %%
# TASK 10: MULTI-PANEL INTERACTIVE SUBPLOTS CONTAINER
# Airline Flights Dataset


import plotly.graph_objects as go
from plotly.subplots import make_subplots

# -------------------------
# Create Multi-Panel Subplot
# -------------------------

fig = make_subplots(
    rows=1,
    cols=2,
    subplot_titles=(
        "Average Flight Price by Class",
        "Flight Price vs Duration"
    )
)

# -------------------------
# PANEL 1: BAR CHART
# Average Price by Travel Class
# -------------------------

class_price = (
    df_airline
    .groupby("class")["price"]
    .mean()
    .reset_index()
)

# %% [markdown]
# Day 12&13
